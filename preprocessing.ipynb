# %% [markdown]
# # FIRE

# %%
fire=pd.read_csv('화재발생건수0018.csv',encoding='utf-8',index_col=0)

fire

del fire.index.name
del fire.columns.name

fire

fire.drop('행정구역별',axis=0,inplace=True)

fire = fire.T

fire.rename(columns={'전국':'화재발생건수'},inplace=True)

fire

# %%
fire.to_csv('화재발생건수.csv',index=True,header=Tr`ue,encoding='utf-8')

# %% [markdown]
# # 해양사고

# %%
acc=pd.read_csv('해양사고0018.csv',encoding='utf-8',index_col=0)

# %%
del acc.index.name
del acc.columns.name

# %%
acc = acc.T

# fire.rename(columns={'전국':'화재발생건수'},inplace=True)

# fire

# %%
acc
# Out:
#         총계 여객선  화물선    어선 유조선  예인선 수상레저기구  기타선
# 2000   780  15   93   586  14   25      -   47
# 2001   779  13  116   537  23   40      -   50
# 2002   775  13  132   509  17   46      -   58
# 2003   767  10  120   483  28   51      -   75
# 2004  1070  20  130   734  24   67      -   95
# 2005   884   8   99   657  24   37      -   59
# 2006   865  17  110   584  43   53      -   58
# 2007   759  13   96   495  31   55      -   69
# 2008  1121  21   74   864  27   59      -   76
# 2009  2103  17  110  1568  33   70      -  305
# 2010  1942  22  133  1380  45   97      -  265
# 2011  2139  22  118  1573  43   86      -  297
# 2012  1854  32  109  1315  45  104      -  249
# 2013  1306  29  107   839  52   78      -  201
# 2014  1565  51  111  1029  51  102      -  221
# 2015  2362  66  115  1621  65   94      -  401
# 2016  2549  65  116  1794  67   77      -  430
# 2017  2882  46  127  1939  73   91    472  134
# 2018  2968  44  112  2013  89  111    469  130

# %%
acc.drop('수상레저기구',axis=1,inplace=True)

# %%
acc=acc.iloc[:,0:2]

# %%
# Out:
# C:\Users\seoyo\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
acc.drop('여객선',axis=1,inplace=True)
# Out:
# C:\Users\seoyo\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
acc.rename(columns={'총계':'해양사고건수'},inplace=True)

# %%
acc
# Out:
#      해양사고건수
# 2000    780
# 2001    779
# 2002    775
# 2003    767
# 2004   1070
# 2005    884
# 2006    865
# 2007    759
# 2008   1121
# 2009   2103
# 2010   1942
# 2011   2139
# 2012   1854
# 2013   1306
# 2014   1565
# 2015   2362
# 2016   2549
# 2017   2882
# 2018   2968

# %%
acc.to_csv('해양사고건수.csv',index=True,header=True,encoding='utf-8')

# %% [markdown]
# # 겅강건짐 수진율 19세이상

# %%
hcheck=pd.read_csv('건강검진수진율_만19세이상.csv',encoding='utf-8',index_col=0)


del hcheck.index.name
del hcheck.columns.name

# fire


# fire.rename(columns={'전국':'화재발생건수'},inplace=True)

# fire

# %%
hcheck = hcheck.T

# %%
hcheck
# Out:
#       19세이상(표준화)
# 2001        47.1
# 2005        47.4
# 2007        47.9
# 2008        48.0
# 2009        50.1
# 2010        52.8
# 2011        51.8
# 2012        54.1
# 2013        59.0
# 2014        56.4
# 2015        59.5
# 2016        62.6
# 2017        65.8

# %%
hcheck.to_csv('수진율.csv',index=True,header=True,encoding='utf-8')

# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv',index_col=0)

# %%
df
# Out:
#        대출일반   대출주택      졸업자수      사교육비          인구         자가용        직장가입자  \
# 2000    NaN    NaN       NaN       NaN  47008111.0         NaN          NaN
# 2001    NaN    NaN       NaN       NaN  47370164.0         NaN          NaN
# 2002    NaN    NaN       NaN       NaN  47644736.0         NaN          NaN
# 2003    NaN    NaN       NaN       NaN  47892330.0         NaN          NaN
# 2004    NaN    NaN       NaN       NaN  48082519.0         NaN          NaN
# 2005    NaN    NaN       NaN       NaN  48184561.0         NaN          NaN
# 2006    NaN    NaN       NaN       NaN  48438292.0         NaN          NaN
# 2007    NaN    NaN       NaN  200400.0  48683638.0         NaN          NaN
# 2008    NaN    NaN       NaN  209095.0  49054708.0         NaN          NaN
# 2009    NaN    NaN       NaN  216259.0  49307835.0         NaN   75391264.0
# 2010    NaN    NaN       NaN  208718.0  49554112.0         NaN   88694835.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 2000 to 2019
# Data columns (total 39 columns):
# 대출일반             9 non-null float64
# 대출주택             9 non-null float64
# 졸업자수             7 non-null float64
# 사교육비             12 non-null float64
# 인구               19 non-null float64
# 자가용              5 non-null float64
# 직장가입자            8 non-null float64
# 지역가입자            8 non-null float64
# 사회단체참여율          7 non-null float64
# 수출               19 non-null float64
# 수입               19 non-null float64
# 실질국내총생산(GDP)     18 non-null float64
# 1인당주거면적          8 non-null float64
# 고등교육이수율          19 non-null float64
# 원자료              19 non-null float64
# e러닝시장규모          16 non-null float64
# 문화여가지출률          13 non-null float64
# 지니계수             8 non-null float64
# 다문화출생아수          11 non-null float64
# 전국 이혼건수          19 non-null float64
# TV (%)           10 non-null float64
# 라디오 (%)          10 non-null float64
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50,figsize=(20,16))
plt.show()
